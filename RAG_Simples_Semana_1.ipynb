# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas-bruzzone/RAG-Experiments/blob/main/RAG_Simples_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonar o repositório do Hugging Face
# !git clone https://huggingface.co/datasets/explodinggradients/Sample_Docs_Markdown
# Out:
# Cloning into 'Sample_Docs_Markdown'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 31 (delta 5), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (31/31), 131.87 KiB | 3.00 MiB/s, done.

# %%
import os

# Ensure the destination directory exists
destination_dir = '/content/drive/MyDrive/Colab Notebooks/RAG-Experiments/documents'
os.makedirs(destination_dir, exist_ok=True)

# Move the files
source_dir = '/content/Sample_Docs_Markdown/'
# !mv "{source_dir}"* "{destination_dir}"

# %%
# List the files in the destination directory to confirm the move
destination_dir = '/content/drive/MyDrive/Colab Notebooks/RAG-Experiments/documents'
# !ls -l "{destination_dir}"
# Out:
# total 62
# -rw-------+ 1 root root   231 Oct 14 18:01 advisory-group-members.md
# -rw-------+ 1 root root 16641 Oct 14 18:01 being-an-ally.md
# -rw-------+ 1 root root  2769 Oct 14 18:01 being-inclusive.md
# -rw-------+ 1 root root 11637 Oct 14 18:01 building-diversity-and-inclusion.md
# -rw-------+ 1 root root  1576 Oct 14 18:01 ceo-dib-statement.md
# -rw-------+ 1 root root  4385 Oct 14 18:01 dib-communications-strategy.md
# -rw-------+ 1 root root   747 Oct 14 18:01 dib-events-program.md
# -rw-------+ 1 root root  2517 Oct 14 18:01 dib-goals.md
# -rw-------+ 1 root root  6478 Oct 14 18:01 dib-roundtables.md
# -rw-------+ 1 root root  2001 Oct 14 18:01 dib-speaker-series.md
# -rw-------+ 1 root root 10929 Oct 14 18:01 dib-sponsorship-program.md
# -rw-------+ 1 root root    31 Oct 14 18:01 README.md
